# %% [markdown]
# ## Entrenamiento de modelos usando Pycaret

# %%
import pandas as pd
import joblib
import os

os.chdir('../')

# %% [markdown]
# #### Cargar datos de entrenamiento

# %%
df_train = joblib.load("datos/data_train.joblib")

# %%
df_train.head()
# Out:
#                                 motivo departamento_inmueble  \
# 4279                         Empleados             ANTIOQUIA
# 8278   Crédito hipotecario de vivienda                  META
# 6684   Crédito hipotecario de vivienda    NORTE DE SANTANDER
# 12351  Crédito hipotecario de vivienda             ANTIOQUIA
# 10770  Crédito hipotecario de vivienda             SANTANDER
#
#       municipio_inmueble                         barrio vias_pavimentadas  \
# 4279              ITAGUI                        Ditares                Si
# 8278        PUERTO LOPEZ                      SANTANDER                Si
# 6684              CUCUTA                PRADOS DEL ESTE                Si
# 12351           RIONEGRO  Sector San Antonio de Pereira                Si
# 10770              GIRON                 URB. MARIANELA                No
#
#       sardineles_en_las_vias andenes_en_las_vias  estrato topografia_sector  \
# 4279                      No                  No      4.0            Ligera
# 8278                      Si                  Si      3.0             Plano
# 6684                      Si                  Si      3.0             Plano
# 12351                     Si                  Si      4.0             Plano
# 10770                     No                  Si      2.0            Ligera
#
#        demanda_interes  ... calidad_acabados_banos estado_acabados_cocina  \
# 4279               2.0  ...                    2.0                    3.0
# 8278               2.0  ...                    1.0                    3.0
# 6684               2.0  ...                    2.0                    3.0
# 12351              3.0  ...                    2.0                    3.0
# 10770              2.0  ...                    1.0                    3.0
#
#       calidad_acabados_cocina tipo_garaje  numero_total_de_garajes  \
# 4279                      2.0         2.0                      1.0
# 8278                      1.0         0.0                      0.0
# 6684                      1.0         3.0                      1.0
# 12351                     2.0         0.0                      0.0
# 10770                     3.0         0.0                      0.0
#
#       total_cupos_parquedaro tipo_deposito numero_total_depositos area_libre  \
# 4279                     1.0             0                    0.0         No
# 8278                     0.0             0                    0.0          0
# 6684                     1.0             0                    0.0         Si
# 12351                    0.0             0                    0.0         No
# 10770                    0.0             0                    0.0         No
#
#       clean_valor_total_avaluo
# 4279               194906580.0
# 8278               122794500.0
# 6684               161650000.0
# 12351              226860000.0
# 10770              111707200.0
#
# [5 rows x 90 columns]

# %%
df_train.shape
# Out:
# (10155, 90)

# %% [markdown]
# #### Cargar encoder y selector de variables

# %%
import joblib
fwiz = joblib.load("modelos/fwiz.joblib")
cat_econder = joblib.load("modelos/cat_econder.joblib")

# %% [markdown]
# #### Aplicar encoder y selector de variables

# %%
X_train_t = cat_econder.transform(df_train.drop(columns=['clean_valor_total_avaluo']))

# %%
X_train_selected = pd.concat([fwiz.transform(X_train_t), df_train['clean_valor_total_avaluo']], axis=1)

# %% [markdown]
# #### Realizar experimento con pycaret

# %%
from pycaret.regression import *

# %%
reg = setup(data=X_train_selected, target='clean_valor_total_avaluo', train_size=0.2, log_experiment=True, experiment_name='reg_experiments', log_plots=True)
# Out:
# <style type="text/css">
# #T_5e45c_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5e45c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e45c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5e45c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5e45c_row0_col1" class="data row0 col1" >559</td>
#     </tr>
#     <tr>
#       <th id="T_5e45c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5e45c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5e45c_row1_col1" class="data row1 col1" >clean_valor_total_avaluo</td>
#     </tr>
#     <tr>
#       <th id="T_5e45c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5e45c_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_5e45c_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_5e45c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5e45c_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_5e45c_row3_col1" class="data row3 col1" >(10155, 104)</td>
#     </tr>
#     <tr>
#       <th id="T_5e45c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5e45c_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_5e45c_row4_col1" class="data row4 col1" >(10155, 104)</td>
#     </tr>
#     <tr>
#       <th id="T_5e45c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5e45c_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_5e45c_row5_col1" class="data row5 col1" >(2031, 104)</td>
#     </tr>
#     <tr>
#       <th id="T_5e45c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5e45c_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_5e45c_row6_col1" class="data row6 col1" >(8124, 104)</td>
#     </tr>
#     <tr>
#       <th id="T_5e45c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5e45c_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_5e45c_row7_col1" class="data row7 col1" >103</td>
#     </tr>
#     <tr>
#       <th id="T_5e45c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5e45c_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_5e45c_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5e45c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5e45c_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_5e45c_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_5e45c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5e45c_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_5e45c_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_5e45c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5e45c_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_5e45c_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_5e45c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5e45c_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_5e45c_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_5e45c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5e45c_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_5e45c_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_5e45c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5e45c_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_5e45c_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_5e45c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5e45c_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_5e45c_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5e45c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5e45c_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_5e45c_row16_col1" class="data row16 col1" >MlflowLogger</td>
#     </tr>
#     <tr>
#       <th id="T_5e45c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5e45c_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_5e45c_row17_col1" class="data row17 col1" >reg_experiments</td>
#     </tr>
#     <tr>
#       <th id="T_5e45c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_5e45c_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_5e45c_row18_col1" class="data row18 col1" >5f76</td>
#     </tr>
#   </tbody>
# </table>
# 2023/11/02 18:54:27 INFO mlflow.tracking.fluent: Experiment with name 'reg_experiments' does not exist. Creating a new experiment.

# %%
top5 = compare_models(n_select=5, exclude=(['ransac', 'knn']), sort='MAPE', fold=5)
# Out:
# <style type="text/css">
# #T_02804_ th {
#   text-align: left;
# }
# #T_02804_row0_col0, #T_02804_row0_col2, #T_02804_row0_col3, #T_02804_row0_col4, #T_02804_row1_col0, #T_02804_row1_col1, #T_02804_row1_col2, #T_02804_row1_col3, #T_02804_row1_col4, #T_02804_row1_col5, #T_02804_row1_col6, #T_02804_row2_col0, #T_02804_row2_col1, #T_02804_row2_col2, #T_02804_row2_col3, #T_02804_row2_col4, #T_02804_row2_col5, #T_02804_row2_col6, #T_02804_row3_col0, #T_02804_row3_col1, #T_02804_row3_col2, #T_02804_row3_col3, #T_02804_row3_col4, #T_02804_row3_col5, #T_02804_row3_col6, #T_02804_row4_col0, #T_02804_row4_col1, #T_02804_row4_col2, #T_02804_row4_col3, #T_02804_row4_col4, #T_02804_row4_col5, #T_02804_row4_col6, #T_02804_row5_col0, #T_02804_row5_col1, #T_02804_row5_col5, #T_02804_row5_col6, #T_02804_row6_col0, #T_02804_row6_col1, #T_02804_row6_col2, #T_02804_row6_col3, #T_02804_row6_col4, #T_02804_row6_col5, #T_02804_row6_col6, #T_02804_row7_col0, #T_02804_row7_col1, #T_02804_row7_col2, #T_02804_row7_col3, #T_02804_row7_col4, #T_02804_row7_col5, #T_02804_row7_col6, #T_02804_row8_col0, #T_02804_row8_col1, #T_02804_row8_col2, #T_02804_row8_col3, #T_02804_row8_col4, #T_02804_row8_col5, #T_02804_row8_col6, #T_02804_row9_col0, #T_02804_row9_col1, #T_02804_row9_col2, #T_02804_row9_col3, #T_02804_row9_col4, #T_02804_row9_col5, #T_02804_row9_col6, #T_02804_row10_col0, #T_02804_row10_col1, #T_02804_row10_col2, #T_02804_row10_col3, #T_02804_row10_col4, #T_02804_row10_col5, #T_02804_row10_col6, #T_02804_row11_col0, #T_02804_row11_col1, #T_02804_row11_col2, #T_02804_row11_col3, #T_02804_row11_col4, #T_02804_row11_col5, #T_02804_row11_col6, #T_02804_row12_col0, #T_02804_row12_col1, #T_02804_row12_col2, #T_02804_row12_col3, #T_02804_row12_col4, #T_02804_row12_col5, #T_02804_row12_col6, #T_02804_row13_col0, #T_02804_row13_col1, #T_02804_row13_col2, #T_02804_row13_col3, #T_02804_row13_col4, #T_02804_row13_col5, #T_02804_row13_col6, #T_02804_row14_col0, #T_02804_row14_col1, #T_02804_row14_col2, #T_02804_row14_col3, #T_02804_row14_col4, #T_02804_row14_col5, #T_02804_row14_col6, #T_02804_row15_col0, #T_02804_row15_col1, #T_02804_row15_col2, #T_02804_row15_col3, #T_02804_row15_col4, #T_02804_row15_col5, #T_02804_row15_col6, #T_02804_row16_col0, #T_02804_row16_col1, #T_02804_row16_col2, #T_02804_row16_col3, #T_02804_row16_col4, #T_02804_row16_col5, #T_02804_row16_col6, #T_02804_row17_col0, #T_02804_row17_col1, #T_02804_row17_col2, #T_02804_row17_col3, #T_02804_row17_col4, #T_02804_row17_col5, #T_02804_row17_col6, #T_02804_row18_col0, #T_02804_row18_col1, #T_02804_row18_col2, #T_02804_row18_col3, #T_02804_row18_col4, #T_02804_row18_col5, #T_02804_row18_col6 {
#   text-align: left;
# }
# #T_02804_row0_col1, #T_02804_row0_col5, #T_02804_row0_col6, #T_02804_row5_col2, #T_02804_row5_col3, #T_02804_row5_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_02804_row0_col7, #T_02804_row1_col7, #T_02804_row2_col7, #T_02804_row3_col7, #T_02804_row4_col7, #T_02804_row5_col7, #T_02804_row6_col7, #T_02804_row7_col7, #T_02804_row9_col7, #T_02804_row10_col7, #T_02804_row11_col7, #T_02804_row12_col7, #T_02804_row13_col7, #T_02804_row14_col7, #T_02804_row15_col7, #T_02804_row17_col7, #T_02804_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_02804_row8_col7, #T_02804_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_02804_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02804_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_02804_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_02804_row0_col1" class="data row0 col1" >38224086.3627</td>
#       <td id="T_02804_row0_col2" class="data row0 col2" >10040325892926634.0000</td>
#       <td id="T_02804_row0_col3" class="data row0 col3" >96852301.0325</td>
#       <td id="T_02804_row0_col4" class="data row0 col4" >0.8502</td>
#       <td id="T_02804_row0_col5" class="data row0 col5" >0.2165</td>
#       <td id="T_02804_row0_col6" class="data row0 col6" >0.1621</td>
#       <td id="T_02804_row0_col7" class="data row0 col7" >1.1800</td>
#     </tr>
#     <tr>
#       <th id="T_02804_level0_row1" class="row_heading level0 row1" >xgboost</th>
#       <td id="T_02804_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#       <td id="T_02804_row1_col1" class="data row1 col1" >40774324.8000</td>
#       <td id="T_02804_row1_col2" class="data row1 col2" >9254391587746612.0000</td>
#       <td id="T_02804_row1_col3" class="data row1 col3" >94747179.2000</td>
#       <td id="T_02804_row1_col4" class="data row1 col4" >0.8584</td>
#       <td id="T_02804_row1_col5" class="data row1 col5" >0.2370</td>
#       <td id="T_02804_row1_col6" class="data row1 col6" >0.1733</td>
#       <td id="T_02804_row1_col7" class="data row1 col7" >0.1520</td>
#     </tr>
#     <tr>
#       <th id="T_02804_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_02804_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_02804_row2_col1" class="data row2 col1" >41162216.5531</td>
#       <td id="T_02804_row2_col2" class="data row2 col2" >9192001017699348.0000</td>
#       <td id="T_02804_row2_col3" class="data row2 col3" >93939430.5379</td>
#       <td id="T_02804_row2_col4" class="data row2 col4" >0.8581</td>
#       <td id="T_02804_row2_col5" class="data row2 col5" >0.2361</td>
#       <td id="T_02804_row2_col6" class="data row2 col6" >0.1736</td>
#       <td id="T_02804_row2_col7" class="data row2 col7" >0.1280</td>
#     </tr>
#     <tr>
#       <th id="T_02804_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_02804_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_02804_row3_col1" class="data row3 col1" >42780427.1562</td>
#       <td id="T_02804_row3_col2" class="data row3 col2" >9664976974867856.0000</td>
#       <td id="T_02804_row3_col3" class="data row3 col3" >95856337.8392</td>
#       <td id="T_02804_row3_col4" class="data row3 col4" >0.8510</td>
#       <td id="T_02804_row3_col5" class="data row3 col5" >0.2379</td>
#       <td id="T_02804_row3_col6" class="data row3 col6" >0.1787</td>
#       <td id="T_02804_row3_col7" class="data row3 col7" >0.3120</td>
#     </tr>
#     <tr>
#       <th id="T_02804_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_02804_row4_col0" class="data row4 col0" >Random Forest Regressor</td>
#       <td id="T_02804_row4_col1" class="data row4 col1" >41507662.6435</td>
#       <td id="T_02804_row4_col2" class="data row4 col2" >10566499586375296.0000</td>
#       <td id="T_02804_row4_col3" class="data row4 col3" >101077549.3332</td>
#       <td id="T_02804_row4_col4" class="data row4 col4" >0.8382</td>
#       <td id="T_02804_row4_col5" class="data row4 col5" >0.2503</td>
#       <td id="T_02804_row4_col6" class="data row4 col6" >0.1794</td>
#       <td id="T_02804_row4_col7" class="data row4 col7" >0.4520</td>
#     </tr>
#     <tr>
#       <th id="T_02804_level0_row5" class="row_heading level0 row5" >gbr</th>
#       <td id="T_02804_row5_col0" class="data row5 col0" >Gradient Boosting Regressor</td>
#       <td id="T_02804_row5_col1" class="data row5 col1" >42735171.6789</td>
#       <td id="T_02804_row5_col2" class="data row5 col2" >8648254661906214.0000</td>
#       <td id="T_02804_row5_col3" class="data row5 col3" >92015680.3124</td>
#       <td id="T_02804_row5_col4" class="data row5 col4" >0.8656</td>
#       <td id="T_02804_row5_col5" class="data row5 col5" >0.2455</td>
#       <td id="T_02804_row5_c

# %% [markdown]
# #### Exportar mejor modelo

# %%
final_best = finalize_model(top5[0])

# %%
save_model(final_best, 'modelos/best_model-pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['barrio_50', 'barrio_90',
#                                               'area_valorada', 'barrio_10',
#                                               'cocina', 'estrato',
#                                               'municipio_inmueble_50',
#                                               'total_cupos_parquedaro',
#                                               'vetustez', 'topografia_sector_75',
#                                               'tipo_inmueble_25',
#                                               'tipo_inmueble_10',
#                                               'departamento_inmueble_10',
#                                               'municipio_inmueble_10',
#                                               'tipo_garaje'...
#                                               'estado_acabados_cocina',
#                                               'departamento_inmueble_90',
#                                               'sardineles_en_las_vias_10',
#                                               'calidad_acabados_pisos',
#                                               'demanda_interes', 'alamedas_10', ...],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=[],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('actual_estimator',
#                   <catboost.core.CatBoostRegressor object at 0x0000029512506730>)]),
#  'modelos/best_model-pipeline.pkl')
