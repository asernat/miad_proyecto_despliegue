# %%
import pandas as pd
import joblib
import os

os.chdir('../')

# %%
df_test = joblib.load("datos/data_test.joblib")

# %%
import joblib

fwiz = joblib.load("modelos/fwiz.joblib")
cat_econder = joblib.load("modelos/cat_econder.joblib")
vars_dict = joblib.load("modelos/vars_dict.joblib")
# Out:
# Imported 0.3.2 version. Select nrows to a small number when running on huge datasets.
# output = featurewiz(dataname, target, corr_limit=0.90, verbose=2, sep=',',
# 		header=0, test_data='',feature_engg='', category_encoders='',
# 		dask_xgboost_flag=False, nrows=None, skip_sulov=False, skip_xgboost=False)
# Create new features via 'feature_engg' flag : ['interactions','groupby','target']

# %%
import mlflow

# %%
import mlflow

experiment_name = "optimizacion"  # Reemplaza <nombre_del_experimento> con el nombre del experimento que deseas buscar

experiment = mlflow.get_experiment_by_name(experiment_name)

if experiment is not None:
    experiment_id = experiment.experiment_id
    print("Experiment ID:", experiment_id)
else:
    print("El experimento no existe.")
# Out:
# Experiment ID: 910525732961037228

# %%
experiment_id = '910525732961037228'

# %%
runs = mlflow.search_runs(experiment_ids=experiment_id,order_by=['metrics.MAPE_test ASC'])

# %%
runs
# Out:
#                                run_id       experiment_id    status  \
# 0    4fb19a084f734574ac15c095b896d401  910525732961037228  FINISHED
# 1    696e42069de746958522f4c1beca4660  910525732961037228  FINISHED
# 2    2b78ed838ce9474a823801d5f847965e  910525732961037228  FINISHED
# 3    f43253fe93ea43778742ddea4f9d2e10  910525732961037228  FINISHED
# 4    8f72c5151a6542669640e261da73457b  910525732961037228  FINISHED
# ..                                ...                 ...       ...
# 245  eee010222b94451dad4ddfeffc1a0b2e  910525732961037228  FINISHED
# 246  d6bf022781744215bc2049c3f4a3edee  910525732961037228  FINISHED
# 247  2a2a68b340c64fac96646ae23006a175  910525732961037228  FINISHED
# 248  56f8640d87ad4e85af9e1419deb7a1c5  910525732961037228  FINISHED
# 249  59eb7f992de54f5186801a6c88c11971  910525732961037228  FINISHED
#
#                                           artifact_uri  \
# 0    file:///e:/Importante/Estudios/Maestria/11%20D...
# 1    file:///e:/Importante/Estudios/Maestria/11%20D...
# 2    file:///e:/Importante/Estudios/Maestria/11%20D...
# 3    file:///e:/Importante/Estudios/Maestria/11%20D...
# 4    file:///e:/Importante/Estudios/Maestria/11%20D...
# ..                                                 ...
# 245  file:///e:/Importante/Estudios/Maestria/11%20D...
# 246  file:///e:/Importante/Estudios/Maestria/11%20D...
# 247  file:///e:/Importante/Estudios/Maestria/11%20D...
# 248  file:///e:/Importante/Estudios/Maestria/11%20D...
# 249  file:///e:/Importante/Estudios/Maestria/11%20D...
#
#                           start_time                         end_time  \
# 0   2023-11-20 03:56:38.477000+00:00 2023-11-20 03:58:07.052000+00:00
# 1   2023-11-20 03:35:11.363000+00:00 2023-11-20 03:36:28.331000+00:00
# 2   2023-11-20 03:02:59.722000+00:00 2023-11-20 03:03:18.623000+00:00
# 3   2023-11-20 02:59:37.899000+00:00 2023-11-20 03:00:04.906000+00:00
# 4   2023-11-20 03:36:28.341000+00:00 2023-11-20 03:38:02.375000+00:00
# ..                               ...                              ...
# 245 2023-11-20 03:19:40.132000+00:00 2023-11-20 03:19:46.191000+00:00
# 246 2023-11-20 03:16:12.700000+00:00 2023-11-20 03:16:24.283000+00:00
# 247 2023-11-20 03:31:26.743000+00:00 2023-11-20 03:31:35.958000+00:00
# 248 2023-11-20 03:35:02.319000+00:00 2023-11-20 03:35:11.345000+00:00
# 249 2023-11-20 03:17:57.731000+00:00 2023-11-20 03:18:06.256000+00:00
#
#      metrics.MAPE_train  metrics.MAPE_test params.max_depth  \
# 0              0.153060           0.211720                4
# 1              0.152932           0.216201                4
# 2              0.146194           0.223004                5
# 3              0.140543           0.223716                7
# 4              0.147760           0.224003                5
# ..                  ...                ...              ...
# 245            0.356313           0.747591                3
# 246            0.355295           0.749739                3
# 247            0.475144           0.786356                2
# 248            0.475282           0.788151                2
# 249            0.476292           0.790961                2
#
#     params.n_estimators params.learning_rate tags.mlflow.user  \
# 0                   436  0.16946215321744781            Santi
# 1                   380  0.12186357347438692            Santi
# 2                   481  0.07517700814642803            Santi
# 3                   473   0.0623103517394323            Santi
# 4                   365  0.09491019715004896            Santi
# ..                  ...                  ...              ...
# 245                 180                 None            Santi
# 246                 390                 None            Santi
# 247                 492                 None            Santi
# 248                 471                 None            Santi
# 249                 453                 None            Santi
#
#     tags.mlflow.source.type  \
# 0                     LOCAL
# 1                     LOCAL
# 2                     LOCAL
# 3                     LOCAL
# 4                     LOCAL
# ..                      ...
# 245                   LOCAL
# 246                   LOCAL
# 247                   LOCAL
# 248                   LOCAL
# 249                   LOCAL
#
#                                tags.mlflow.source.name tags.mlflow.runName
# 0    D:\ambientes\despliegue2\lib\site-packages\ipy...     optimizacion_gb
# 1    D:\ambientes\despliegue2\lib\site-packages\ipy...     optimizacion_gb
# 2    D:\ambientes\despliegue2\lib\site-packages\ipy...    optimizacion_xgb
# 3    D:\ambientes\despliegue2\lib\site-packages\ipy...    optimizacion_xgb
# 4    D:\ambientes\despliegue2\lib\site-packages\ipy...     optimizacion_gb
# ..                                                 ...                 ...
# 245  D:\ambientes\despliegue2\lib\site-packages\ipy...     optimizacion_rf
# 246  D:\ambientes\despliegue2\lib\site-packages\ipy...     optimizacion_rf
# 247  D:\ambientes\despliegue2\lib\site-packages\ipy...     optimizacion_rf
# 248  D:\ambientes\despliegue2\lib\site-packages\ipy...     optimizacion_rf
# 249  D:\ambientes\despliegue2\lib\site-packages\ipy...     optimizacion_rf
#
# [250 rows x 15 columns]

# %%
best_run = runs.iloc[0]

# %%
best_run
# Out:
# run_id                                      4fb19a084f734574ac15c095b896d401
# experiment_id                                             910525732961037228
# status                                                              FINISHED
# artifact_uri               file:///e:/Importante/Estudios/Maestria/11%20D...
# start_time                                  2023-11-20 03:56:38.477000+00:00
# end_time                                    2023-11-20 03:58:07.052000+00:00
# metrics.MAPE_train                                                   0.15306
# metrics.MAPE_test                                                    0.21172
# params.max_depth                                                           4
# params.n_estimators                                                      436
# params.learning_rate                                     0.16946215321744781
# tags.mlflow.user                                                       Santi
# tags.mlflow.source.type                                                LOCAL
# tags.mlflow.source.name    D:\ambientes\despliegue2\lib\site-packages\ipy...
# tags.mlflow.runName                                          optimizacion_gb
# Name: 0, dtype: object
